# %% [markdown]
# # 03 — Regresión de Precios de Alquiler
#
# **Objetivo:** Entrenar y comparar modelos de regresión para predecir el precio mensual.
#
# **Entradas:** `data/processed/inmuebles_clean.csv`
# **Salidas:** Modelos en `02_ml_models/models/`, métricas en `model_evaluation.md`
#
# ---
#
# ## Contenido
#
# 1. **Preparación de datos** — Train/test split (80/20), pipeline de `src/preprocessing/`
# 2. **Baseline** — Regresión Lineal como referencia mínima
# 3. **Random Forest** — Hiperparámetros de `config/model_params.yaml`
# 4. **XGBoost** — Gradient Boosting con early stopping
# 5. **LightGBM** — Alternativa eficiente para datasets grandes
# 6. **Comparación** — Tabla MAE / RMSE / R² para los tres modelos
# 7. **Cross-Validation** — 5-fold CV para estimar varianza del modelo
# 8. **Guardado del mejor modelo** — `joblib.dump()` a `models/mejor_modelo.pkl`
#
# ---
#
# > El análisis de features continúa en `04_analisis_features.ipynb`.

# %%
# TODO: importar sklearn, xgboost, lightgbm, pandas, joblib
# TODO: cargar config desde config/model_params.yaml
# TODO: aplicar pipeline de src.preprocessing
