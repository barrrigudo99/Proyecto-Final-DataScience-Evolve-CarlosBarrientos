# %% [markdown]
# # 02 — Visualizaciones del Mercado de Alquiler
#
# **Objetivo:** Comunicar visualmente los patrones del mercado de alquiler español.
#
# **Entradas:** `data/processed/inmuebles_clean.csv`
# **Salidas:** Gráficos en `01_eda_analysis/output/`
#
# ---
#
# ## Contenido
#
# 1. **Precio medio por ciudad** — Barplot comparativo entre ciudades
# 2. **Precio vs. metros cuadrados** — Scatter con tendencia y color por ciudad
# 3. **Mapa de calor de precios** — Precio medio por distrito en mapa Folium interactivo
# 4. **Evolución temporal** — Precio medio mensual (si hay datos de varias fechas)
# 5. **Correlación de variables** — Heatmap de correlaciones (precio, metros, habitaciones)
# 6. **Distribución precio/m²** — Violin plot por ciudad
# 7. **Top distritos más caros** — Ranking por ciudad
#
# ---
#
# > Los gráficos se guardan en alta resolución en `output/` para incluir en la memoria del proyecto.

# %%
# TODO: importar pandas, seaborn, plotly, folium
# TODO: cargar df desde data/processed/inmuebles_clean.csv
# TODO: configurar estilo de seaborn y paleta de colores del proyecto
