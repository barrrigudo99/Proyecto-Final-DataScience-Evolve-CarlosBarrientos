# %% [markdown]
# # 06 — Agente Inteligente con LangGraph
#
# **Objetivo:** Implementar y probar el agente RAG completo con LangGraph,
# capaz de responder preguntas complejas sobre el mercado de alquiler.
#
# **Entradas:** Índice ChromaDB, SQLite, modelo ML
# **Salidas:** Demostración interactiva del agente en el notebook
#
# ---
#
# ## Contenido
#
# 1. **Definición del grafo** — Nodos razonar / ejecutar_tool con LangGraph
# 2. **Registro de tools** — buscar_anuncios, estadisticas_mercado, predecir_precio
# 3. **Pruebas de queries simples** — '¿Cuánto cuesta alquilar en Madrid?'
# 4. **Pruebas de razonamiento multi-paso** — '¿En qué ciudad es más barato vivir con 2 habitaciones?'
# 5. **Visualización del grafo** — Diagrama del flujo de ejecución
# 6. **Análisis de latencia y coste** — Tokens consumidos por query
# 7. **Casos límite** — Preguntas fuera del dominio, ambigüedades
#
# ---
#
# > El agente en producción se lanza desde `app.py`.

# %%
# TODO: from 03_rag_agent.src.agent import crear_agente
# TODO: from langchain_core.messages import HumanMessage
# TODO: agente = crear_agente()
# TODO: resultado = agente.invoke({"messages": [HumanMessage("¿Cuánto cuesta alquilar en Madrid?")]})
