# %% [markdown]
# # 05 — Configuración del Sistema RAG
#
# **Objetivo:** Construir el índice vectorial y evaluar la calidad de la recuperación
# antes de conectarlo al agente.
#
# **Entradas:** `data/processed/inmuebles_clean.csv` o SQLite
# **Salidas:** Índice ChromaDB en `data/embeddings/chroma/`
#
# ---
#
# ## Contenido
#
# 1. **Conversión a documentos** — Usar `document_loader.py` para generar textos naturales
# 2. **Generación de embeddings** — OpenAI text-embedding-3-small sobre el corpus
# 3. **Indexación en ChromaDB** — Persistir el índice vectorial
# 4. **Pruebas de recuperación** — Queries de ejemplo y análisis de relevancia
# 5. **Evaluación del retriever** — Precision@k y comparación similarity vs MMR
# 6. **Optimización de chunk size** — Impacto del tamaño del texto en la calidad
#
# ---
#
# > Este notebook valida el retriever antes de conectarlo al agente en `06_agente_langgraph.ipynb`.

# %%
# TODO: from 03_rag_agent.src.document_loader import cargar_documentos_desde_db
# TODO: from 03_rag_agent.src.embeddings import generar_embeddings
# TODO: from 03_rag_agent.src.vectorstore import buscar_similares
