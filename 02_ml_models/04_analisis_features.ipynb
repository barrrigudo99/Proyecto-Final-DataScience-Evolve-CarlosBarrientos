# %% [markdown]
# # 04 — Análisis de Importancia de Features
#
# **Objetivo:** Entender qué variables tienen mayor impacto en el precio de alquiler
# usando feature importance nativa y valores SHAP.
#
# **Entradas:** Modelo entrenado en `models/mejor_modelo.pkl`, dataset de test
# **Salidas:** Gráficos SHAP en `01_eda_analysis/output/`
#
# ---
#
# ## Contenido
#
# 1. **Feature Importance nativa** — Importancia por ganancia/frecuencia del modelo
# 2. **SHAP Summary Plot** — Impacto global de cada feature sobre las predicciones
# 3. **SHAP Dependence Plots** — Relación no lineal de metros y precio con el target
# 4. **SHAP Waterfall** — Explicación individual de una predicción concreta
# 5. **Análisis de errores** — En qué tipo de anuncios se equivoca más el modelo
# 6. **Conclusiones** — Features más relevantes e implicaciones para el negocio
#
# ---
#
# > Estos resultados alimentan la documentación en `docs/RESULTADOS_CLAVE.md`.

# %%
# TODO: importar shap, joblib, pandas, matplotlib
# TODO: cargar modelo desde models/mejor_modelo.pkl
# TODO: shap.Explainer(modelo) y shap_values = explainer(X_test)
